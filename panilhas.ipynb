# %% [markdown]
# <a href="https://colab.research.google.com/github/tilpmaria/python/blob/main/panilhas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ❤ **sua experiencia trabalhando em equipe** ❣

# %%
import pandas as pd

# %%
dados = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vRwQNSzd_MGV3I4Sn61czP31c6v8NhvwkycbUlKE26wC9miFji22nyDIUJNiBJzA-clcIoQcB22IX2s/pub?gid=200478666&single=true&output=csv")

# %%
dados
# Out:
#   Carimbo de data/hora Pontuação  \
# 0  08/09/2025 11:09:13    7 / 14
# 1  08/09/2025 11:18:24    0 / 14
#
#   \nConte sobre um momento em que você e um colega trabalharam juntos e o que vocês aprenderam com isso.   \
# 0   Nossas atividades em grupo sempre teve colabo...
# 1  tivemos muitas divergências porem, todos colab...
#
#   \nConte sobre um momento em que você e um colega trabalharam juntos e o que vocês aprenderam com isso. .1  \
# 0                                                NaN
# 1                         tivemos muitas divergência
#
#    Endereço de e-mail
# 0                 NaN
# 1                 NaN
